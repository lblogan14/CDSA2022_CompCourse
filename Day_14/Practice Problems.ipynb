# %% [markdown]
# # Practice Problems
#
# By request, here are some practice problems. The problems come from the book I used in my computational course. The book we used was _Computational Physics_ by Mark Newman (the first edition). I find it to be a really useful reference book for python.
#
#
# ##Problem 1 (3.2 - Curve Plotting)
#
# Although the ```plot``` function is designed primarily for plotting standard _xy_ graphs, it can be adapted for other kidns of plotting as well.
#
# a) ***Make a plot of the so-called _deltoid_ curve***, which is defined parametrically by the equations:
#
# $x = 2cosθ + cos2θ, \quad \quad y = 2sinθ - sin2θ$
#
# where $0 ≤ θ < 2π$. Take a set of values of θ between zero and 2π and calculate _x_ and _y_ for each fromm the equations above, and then plot _y_ as a function of _x_.
#
# b) Taking this approach a step further, one can make a polar plot $r = f(θ)$ for some function _f_ by calculating _r_ for a range of values of θ and then converting _r_ and θ to Cartesian coordinates using the standard equations $x = rcosθ, y = rsinθ$. Use this method to ***make a plot of the Galilean spiral*** $r= θ^2$ for $0 ≤ θ ≤ 10π$.
#
# c) Using the same method, ***make a polar plot of "Fey's function"***
#
# $r = e^{cosθ} - 2cos4θ + sin^5 \frac{θ}{12}$
#
# in the range $0 ≤ θ \le 24π$.

# %%
##imports here



## part a



##part b



##part c

# %% [markdown]
# ## Problem 2 (8.8 - Space garbage)
#
# A heavy steel rod and a spherical ball-bearing, discarded by a passing spaceship, are floating in zero gravity and the ball bearing is orbiting around the rod under the effect of its gravitational pull (ask Caroline to draw this -- after you try drawing it! -- if you need assistance visualizing).
#
#
# For simplicity we'll assume that the rod is of negligible cross-seciton and heavy enough that it doesn't move significantly, and thatthe ball bearing is orbiting around the rod's mid-point in a plane perpendicular to the rod.
#
# Note: treating the rod as a line of mass _M_ and length _L_ and the ball bearing as a point mass _m_, the attractive force F felt by the ball bearing in the direction toward the center of the rod is given by:
#
# $F = \frac{GMm}{L} (x^2 + y^2)^{\frac{1}{2}} \int _{-L/2} ^{L/2} \frac{dz}{(x^2 + y^2 + z^2)^{3/2}}$
#
# where _G_ is Newton's gravitational constant and _x_ and _y_ are the coordinates of the ball bearing in the plane perpendicular to the rod. The integral can be done in clsoed form and gives:
#
# $F = \frac{GMm}{((x^2 + y^2)(x^2 + y^2 + L^2/4))^{1/2}} $
#
# Hence, the equations of motion for the position _x_, _y_ of the ball bearing in the _xy_-plane are
#
# $\frac{d^2x}{dt^2} = -GM \frac{x}{r^2 (r^2 + L^2/4)^{1/2}} \quad \quad \frac{d^2y}{dt^2} = -GM \frac{y}{r^2 (r^2 + L^2/4)^{1/2}}$
#
# where $ r^2 = x^2 + y^2 $.
#
# **Convert these two second-order equations into four first-order equations using the fact that velocity is the first derivative with respect to time of a spatial coordinate**.
#
# Then, working in units where $G = 1$, ***write a program*** to solve them for $M=10, L=2$, and initial conditions $(x,y) = (1,0)$ with a velocity of +1 in the _y_ direction. Calculate the orbit from $t=0$ to $t=10$ and make a plot of it, meaning a ***plot of $y$ against $x$***. You should find that the ball bearing does not orbit in a circle or an ellipse as a planet does, but has a precessing orbit, which arises becasue teh attractive force ins not a simple $1/r^2$ force as it is for a planet orbitting the Sun.

# %%
##imports here


##constants/conditions of the problem here


##define the differential equations here


##define a DE sovler (e.g. RK2 or RK4) 


##create what you're going to plot



##plot here
